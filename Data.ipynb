# %%
import pandas as pd

# %%
september = pd.read_csv("Resources/september.csv")
august = pd.read_csv("Resources/august.csv")
july = pd.read_csv("Resources/july.csv")
june = pd.read_csv("Resources/june.csv")
may = pd.read_csv("Resources/may.csv")
april = pd.read_csv("Resources/april.csv")
march = pd.read_csv("Resources/march.csv")
february = pd.read_csv("Resources/february.csv")
january = pd.read_csv("Resources/january.csv")

# %%
finaldf = pd.concat([january, february, march, april, may, june, july, august, september])

# %%
finaldf.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 2488220          1818  2020-09-30 23:59:48.8460  2020-10-01 00:30:07.7810
# 2488221          1553  2020-09-30 23:59:53.7240  2020-10-01 00:25:47.1760
# 2488222           626  2020-09-30 23:59:54.6670  2020-10-01 00:10:21.6050
# 2488223           325  2020-09-30 23:59:56.2120  2020-10-01 00:05:21.3060
# 2488224           128  2020-09-30 23:59:57.8350  2020-10-01 00:02:06.0920
#
#          start station id           start station name  \
# 2488220               284        Greenwich Ave & 8 Ave
# 2488221               390  Duffield St & Willoughby St
# 2488222              3901   Stanhope St & Fairview Ave
# 2488223              3148              E 84 St & 1 Ave
# 2488224               439               E 4 St & 2 Ave
#
#          start station latitude  start station longitude  end station id  \
# 2488220               40.739017               -74.002638            3836
# ...

# %%
finaldf['gender'] = finaldf['gender'].map({2: 'female', 1: 'male', 0: 'unknown'})
finaldf
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 2488220          1818  2020-09-30 23:59:48.8460  2020-10-01 00:30:07.7810
# 2488221          1553  2020-09-30 23:59:53.7240  2020-10-01 00:25:47.1760
# 2488222           626  2020-09-30 23:59:54.6670  2020-10-01 00:10:21.6050
# 2488223           325  2020-09-30 23:59:56.2120  2020-10-01 00:05:21.3060
# 2488224           128  2020-09-30 23:59:57.8350  2020-10-01 00:02:06.0920
#
#          start station id               start station name  \
# ...

# %%
finaldf.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                      object
# dtype: object

# %%
finaldf.to_csv("Resources/master.csv")
